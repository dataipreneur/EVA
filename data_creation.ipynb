# %%
##Import and lodadin data

import json

import pandas as pd

f7 = open('raw_response (12).json')


data = json.load(f7)
data.keys()
# Out:
# dict_keys(['banner', 'categories', 'emptySearchResult', 'list', 'locationPreciseEnoughForDelivery', 'numPages', 'pickupWindow', 'returnWindow', 'searchFilterProperties', 'searchId', 'searchLocation', 'suggestedLeadDateTime', 'timeZoneOffset', 'userCountryGuess', 'vehiclePromoAggregate'])

# %%
#data_categories = data['categories']
data_categories = data['categories']
data_categories

data_list = data['list']
data_list
# Out:
# [{'deliveryLabel': None,
#   'distance': 13.0,
#   'distanceLabel': '13 mi',
#   'distanceWithUnit': {'scalar': 13, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Sammamish, WA'],
#    'city': 'Sammamish',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.60535793520545,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.05222933631492,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 5736309,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/5736309'},
#   'rate': {'averageDailyPrice': 78.0,
#    'averageDailyPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'daily': 78.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.07},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 7,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1836352,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1672098106,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Sienna',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'minivan',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2023,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 20.0,
#   'distanceLabel': '19.6 mi',
#   'distanceWithUnit': {'scalar': 20, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Auburn, WA'],
#    'city': 'Auburn',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.325128256413976,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.27533740461918,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 17344425,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/17344425'},
#   'rate': {'averageDailyPrice': 65.0,
#    'averageDailyPriceWithCurrency': {'amount': 65.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 65.0, 'currencyCode': 'USD'},
#    'daily': 65.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.12},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 40,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': True,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1546692,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1655327798,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model 3',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 15.0,
#   'distanceLabel': '15.3 mi',
#   'distanceWithUnit': {'scalar': 15, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Issaquah, WA'],
#    'city': 'Issaquah',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.563520034058854,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.01101017525465,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 3455513,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/3455513'},
#   'rate': {'averageDailyPrice': 78.0,
#    'averageDailyPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'daily': 78.0,
#    'discountSavingsText': None,
#    'monthly': 0.3,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 17,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1564500,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1656205981,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Sienna',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'minivan',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2022,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 9.0,
#   'distanceLabel': '9.3 mi',
#   'distanceWithUnit': {'scalar': 9, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.47521809607739,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.28445835911464,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 1836536,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/1836536'},
#   'rate': {'averageDailyPrice': 70.0,
#    'averageDailyPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'daily': 70.0,
#    'discountSavingsText': None,
#    'monthly': 0.1,
#    'promotionResponse': None,
#    'weekly': 0.0},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 117,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': True,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 800214,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1593846564,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model Y',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2020,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 4.0,
#   'distanceLabel': '4.1 mi',
#   'distanceWithUnit': {'scalar': 4, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.54933850866646,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.30676701092199,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 2685972,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/2685972'},
#   'rate': {'averageDailyPrice': 53.0,
#    'averageDailyPriceWithCurrency': {'amount': 53.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 53.0, 'currencyCode': 'USD'},
#    'daily': 53.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 1,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1869886,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1674156409,
#    'make': 'Ford',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Mustang Mach-E',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2023,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 5.0,
#   'distanceLabel': '5 mi',
#   'distanceWithUnit': {'scalar': 5, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.533982215700945,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.3452763326343,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 11534484,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/11534484'},
#   'rate': {'averageDailyPrice': 70.0,
#    'averageDailyPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'daily': 70.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 22,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': True,
#   'unlimitedMileageBadge': 'Unlimited miles',
#   'vehicle': {'automaticTransmission': True,
#    'id': 1617672,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1658787804,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Prius Prime',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2022,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 13.0,
#   'distanceLabel': '12.9 mi',
#   'distanceWithUnit': {'scalar': 13, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Mountlake Terrace, WA'],
#    'city': 'Mountlake Terrace',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.789908354341826,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.28660732752984,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 20228262,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/20228262'},
#   'rate': {'averageDailyPrice': 54.0,
#    'averageDailyPriceWithCurrency': {'amount': 54.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 54.0, 'currencyCode': 'USD'},
#    'daily': 54.0,
#    'discountSavingsText': None,
#    'monthly': 0.3,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 19,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': 'Unlimited miles',
#   'vehicle': {'automaticTransmission': True,
#    'id': 1799957,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1669448036,
#    'make': 'Hyundai',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Elantra',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2023,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 0.0,
#   'distanceLabel': '< 0.5 mi',
#   'distanceWithUnit': {'scalar': 0, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.609387897233184,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.33511598437703,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 3341459,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/3341459'},
#   'rate': {'averageDailyPrice': 74.0,
#    'averageDailyPriceWithCurrency': {'amount': 74.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 74.0, 'currencyCode': 'USD'},
#    'daily': 74.0,
#    'discountSavingsText': None,
#    'monthly': 0.4,
#    'promotionResponse': None,
#    'weekly': 0.25},
#   'rating': 4.98,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 77,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1289806,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1639168353,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model 3',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 11.0,
#   'distanceLabel': '11.1 mi',
#   'distanceWithUnit': {'scalar': 11, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Tukwila, WA'],
#    'city': 'Tukwila',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.45346601788958,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.2615596487202,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 27934968,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/27934968'},
#   'rate': {'averageDailyPrice': 78.0,
#    'averageDailyPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'daily': 78.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 4.93,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 16,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': 'Unlimited miles',
#   'vehicle': {'automaticTransmission': True,
#    'id': 1719859,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1664318431,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model 3',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2019,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 12.0,
#   'distanceLabel': '11.9 mi',
#   'distanceWithUnit': {'scalar': 12, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.435820739276494,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.29480726276657,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 28442211,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/28442211'},
#   'rate': {'averageDailyPrice': 69.0,
#    'averageDailyPriceWithCurrency': {'amount': 69.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 69.0, 'currencyCode': 'USD'},
#    'daily': 69.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 27,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1730070,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1664950559,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'RAV4 Hybrid',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2022,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 5.0,
#   'distanceLabel': '5.2 mi',
#   'distanceWithUnit': {'scalar': 5, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.53393233860314,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.36459041262151,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 22217867,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/22217867'},
#   'rate': {'averageDailyPrice': 43.0,
#    'averageDailyPriceWithCurrency': {'amount': 43.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 43.0, 'currencyCode': 'USD'},
#    'daily': 43.0,
#    'discountSavingsText': None,
#    'monthly': 0.0,
# ...
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/24616237'},
#   'rate': {'averageDailyPrice': 250.0,
#    'averageDailyPriceWithCurrency': {'amount': 250.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 250.0,
#     'currencyCode': 'USD'},
#    'daily': 250.0,
#    'discountSavingsText': None,
#    'monthly': 0.0,
#    'promotionResponse': None,
#    'weekly': 0.0},
#   'rating': 4.5,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 2,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1508509,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1653413215,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Highlander Hybrid',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 49.0,
#   'distanceLabel': '49 mi',
#   'distanceWithUnit': {'scalar': 49, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Olympia, WA'],
#    'city': 'Olympia',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.032430956345316,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.94736835274267,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 31356089,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/31356089'},
#   'rate': {'averageDailyPrice': 99.0,
#    'averageDailyPriceWithCurrency': {'amount': 99.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 99.0, 'currencyCode': 'USD'},
#    'daily': 99.0,
#    'discountSavingsText': None,
#    'monthly': 0.3,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': None,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 0,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1923205,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1677613946,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model X',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2016,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 21.0,
#   'distanceLabel': '21.3 mi',
#   'distanceWithUnit': {'scalar': 21, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Federal Way, WA'],
#    'city': 'Federal Way',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.29807576510686,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.35831505563073,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 23822125,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/23822125'},
#   'rate': {'averageDailyPrice': 70.0,
#    'averageDailyPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'daily': 70.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 2,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1535769,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1654793531,
#    'make': 'Ford',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Fusion Hybrid',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2017,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 22.0,
#   'distanceLabel': '21.7 mi',
#   'distanceWithUnit': {'scalar': 22, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Federal Way, WA'],
#    'city': 'Federal Way',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.29210608252068,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.31329393975246,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 7163122,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/7163122'},
#   'rate': {'averageDailyPrice': 250.0,
#    'averageDailyPriceWithCurrency': {'amount': 250.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 250.0,
#     'currencyCode': 'USD'},
#    'daily': 250.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': None,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 0,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1898552,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1676047812,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model S',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False}]

# %%
data_list
# Out:
# [{'deliveryLabel': None,
#   'distance': 13.0,
#   'distanceLabel': '13 mi',
#   'distanceWithUnit': {'scalar': 13, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Sammamish, WA'],
#    'city': 'Sammamish',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.60535793520545,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.05222933631492,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 5736309,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/5736309'},
#   'rate': {'averageDailyPrice': 78.0,
#    'averageDailyPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'daily': 78.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.07},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 7,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1836352,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/JP1529d0S5OzxyFRLP5Fmw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1672098106,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Sienna',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'minivan',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2023,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 20.0,
#   'distanceLabel': '19.6 mi',
#   'distanceWithUnit': {'scalar': 20, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Auburn, WA'],
#    'city': 'Auburn',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.325128256413976,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.27533740461918,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 17344425,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/17344425'},
#   'rate': {'averageDailyPrice': 65.0,
#    'averageDailyPriceWithCurrency': {'amount': 65.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 65.0, 'currencyCode': 'USD'},
#    'daily': 65.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.12},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 40,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': True,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1546692,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KpBQIEbLRuiFrM1KaKQBSw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1655327798,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model 3',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 15.0,
#   'distanceLabel': '15.3 mi',
#   'distanceWithUnit': {'scalar': 15, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Issaquah, WA'],
#    'city': 'Issaquah',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.563520034058854,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.01101017525465,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 3455513,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/3455513'},
#   'rate': {'averageDailyPrice': 78.0,
#    'averageDailyPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'daily': 78.0,
#    'discountSavingsText': None,
#    'monthly': 0.3,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 17,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1564500,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/eR5OuNNLQV2mS-ShQJHLvg.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1656205981,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Sienna',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'minivan',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2022,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 9.0,
#   'distanceLabel': '9.3 mi',
#   'distanceWithUnit': {'scalar': 9, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.47521809607739,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.28445835911464,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 1836536,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/1836536'},
#   'rate': {'averageDailyPrice': 70.0,
#    'averageDailyPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'daily': 70.0,
#    'discountSavingsText': None,
#    'monthly': 0.1,
#    'promotionResponse': None,
#    'weekly': 0.0},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 117,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': True,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 800214,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/k1QXzsJgTt2_5raFIwV9Jw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1593846564,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model Y',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2020,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 4.0,
#   'distanceLabel': '4.1 mi',
#   'distanceWithUnit': {'scalar': 4, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.54933850866646,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.30676701092199,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 2685972,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/2685972'},
#   'rate': {'averageDailyPrice': 53.0,
#    'averageDailyPriceWithCurrency': {'amount': 53.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 53.0, 'currencyCode': 'USD'},
#    'daily': 53.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 1,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1869886,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/2wZU-3ZVSZarswI-FaN3gw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1674156409,
#    'make': 'Ford',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Mustang Mach-E',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2023,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 5.0,
#   'distanceLabel': '5 mi',
#   'distanceWithUnit': {'scalar': 5, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.533982215700945,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.3452763326343,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 11534484,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/11534484'},
#   'rate': {'averageDailyPrice': 70.0,
#    'averageDailyPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'daily': 70.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 22,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': True,
#   'unlimitedMileageBadge': 'Unlimited miles',
#   'vehicle': {'automaticTransmission': True,
#    'id': 1617672,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/5hvjOQX1T2Gpo34_VtZGsQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1658787804,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Prius Prime',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2022,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 13.0,
#   'distanceLabel': '12.9 mi',
#   'distanceWithUnit': {'scalar': 13, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Mountlake Terrace, WA'],
#    'city': 'Mountlake Terrace',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.789908354341826,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.28660732752984,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 20228262,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/20228262'},
#   'rate': {'averageDailyPrice': 54.0,
#    'averageDailyPriceWithCurrency': {'amount': 54.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 54.0, 'currencyCode': 'USD'},
#    'daily': 54.0,
#    'discountSavingsText': None,
#    'monthly': 0.3,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 19,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': 'Unlimited miles',
#   'vehicle': {'automaticTransmission': True,
#    'id': 1799957,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/ae0sEqljTSiTM_OjTk9juQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1669448036,
#    'make': 'Hyundai',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Elantra',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2023,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 0.0,
#   'distanceLabel': '< 0.5 mi',
#   'distanceWithUnit': {'scalar': 0, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.609387897233184,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.33511598437703,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 3341459,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/3341459'},
#   'rate': {'averageDailyPrice': 74.0,
#    'averageDailyPriceWithCurrency': {'amount': 74.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 74.0, 'currencyCode': 'USD'},
#    'daily': 74.0,
#    'discountSavingsText': None,
#    'monthly': 0.4,
#    'promotionResponse': None,
#    'weekly': 0.25},
#   'rating': 4.98,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 77,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1289806,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/1YaOZoQTQu2kSzyMMReKeQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1639168353,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model 3',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 11.0,
#   'distanceLabel': '11.1 mi',
#   'distanceWithUnit': {'scalar': 11, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Tukwila, WA'],
#    'city': 'Tukwila',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.45346601788958,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.2615596487202,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 27934968,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/27934968'},
#   'rate': {'averageDailyPrice': 78.0,
#    'averageDailyPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#    'daily': 78.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 4.93,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 16,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': 'Unlimited miles',
#   'vehicle': {'automaticTransmission': True,
#    'id': 1719859,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/H7S8u4GhRo-0Bv-2JP1pdQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1664318431,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model 3',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2019,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 12.0,
#   'distanceLabel': '11.9 mi',
#   'distanceWithUnit': {'scalar': 12, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.435820739276494,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.29480726276657,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 28442211,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/28442211'},
#   'rate': {'averageDailyPrice': 69.0,
#    'averageDailyPriceWithCurrency': {'amount': 69.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 69.0, 'currencyCode': 'USD'},
#    'daily': 69.0,
#    'discountSavingsText': None,
#    'monthly': 0.15,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 27,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1730070,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/KZXT36MgRdm9oloeDrvWsQ.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1664950559,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'RAV4 Hybrid',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2022,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 5.0,
#   'distanceLabel': '5.2 mi',
#   'distanceWithUnit': {'scalar': 5, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/Rj-l4pUgS0awYqFkZ38k-w.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Seattle, WA'],
#    'city': 'Seattle',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.53393233860314,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.36459041262151,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': True,
#    'firstName': 'NOT_USED',
#    'id': 22217867,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/22217867'},
#   'rate': {'averageDailyPrice': 43.0,
#    'averageDailyPriceWithCurrency': {'amount': 43.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 43.0, 'currencyCode': 'USD'},
#    'daily': 43.0,
#    'discountSavingsText': None,
#    'monthly': 0.0,
# ...
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/24616237'},
#   'rate': {'averageDailyPrice': 250.0,
#    'averageDailyPriceWithCurrency': {'amount': 250.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 250.0,
#     'currencyCode': 'USD'},
#    'daily': 250.0,
#    'discountSavingsText': None,
#    'monthly': 0.0,
#    'promotionResponse': None,
#    'weekly': 0.0},
#   'rating': 4.5,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 2,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1508509,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/zvjpX-CdSPy3SF-QmgtV2A.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1653413215,
#    'make': 'Toyota',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Highlander Hybrid',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 49.0,
#   'distanceLabel': '49 mi',
#   'distanceWithUnit': {'scalar': 49, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Olympia, WA'],
#    'city': 'Olympia',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.032430956345316,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.94736835274267,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 31356089,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/31356089'},
#   'rate': {'averageDailyPrice': 99.0,
#    'averageDailyPriceWithCurrency': {'amount': 99.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 99.0, 'currencyCode': 'USD'},
#    'daily': 99.0,
#    'discountSavingsText': None,
#    'monthly': 0.3,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': None,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 0,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1923205,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/g8xa8Kb8Swq3fSgVyG0xbw.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1677613946,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model X',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'suv',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2016,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 21.0,
#   'distanceLabel': '21.3 mi',
#   'distanceWithUnit': {'scalar': 21, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Federal Way, WA'],
#    'city': 'Federal Way',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.29807576510686,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.35831505563073,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 23822125,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/23822125'},
#   'rate': {'averageDailyPrice': 70.0,
#    'averageDailyPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 70.0, 'currencyCode': 'USD'},
#    'daily': 70.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.15},
#   'rating': 5.0,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 2,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1535769,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/-Yy9yvJUTV6IZEeQ_5kb5A.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1654793531,
#    'make': 'Ford',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Fusion Hybrid',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2017,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False},
#  {'deliveryLabel': None,
#   'distance': 22.0,
#   'distanceLabel': '21.7 mi',
#   'distanceWithUnit': {'scalar': 22, 'unit': 'MI', 'unlimited': False},
#   'freeDeliveryPromotion': False,
#   'fuelType': None,
#   'images': [{'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.100x60.jpg'},
#     'verified': False}],
#   'instantBookDisplayed': False,
#   'location': {'address': 'NOT_USED',
#    'addressLines': ['Federal Way, WA'],
#    'city': 'Federal Way',
#    'country': 'US',
#    'id': None,
#    'latitude': 47.29210608252068,
#    'locationSource': 'GOOGLE',
#    'longitude': -122.31329393975246,
#    'precision': {'accuracy': 0.09320565, 'level': 'APPROXIMATE'},
#    'state': 'WA',
#    'timeZone': 'America/Los_Angeles'},
#   'newListing': False,
#   'owner': {'allStarHost': False,
#    'firstName': 'NOT_USED',
#    'id': 7163122,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#     'placeholder': True,
#     'resizableUrlTemplate': None,
#     'thumbnails': {'84x84': 'https://resources.turo.com/resources/img/profile/empty-profile_01_medium__Ha869faa760f43a28da9ca8fbcde22c2d__.png',
#      '300x300': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '225x225': 'https://resources.turo.com/resources/img/profile/empty-profile_01_large__H7cdab5c9c7828f25764b49b1e54f0b39__.png',
#      '32x32': 'https://resources.turo.com/resources/img/profile/empty-profile_01_tiny__H1d3b304549036bd19f7ef997a31d5761__.png'},
#     'verified': False},
#    'lastName': '',
#    'name': 'NOT_USED',
#    'url': 'https://turo.com/us/en/drivers/7163122'},
#   'rate': {'averageDailyPrice': 250.0,
#    'averageDailyPriceWithCurrency': {'amount': 250.0, 'currencyCode': 'USD'},
#    'baseDailyRentalPriceWithCurrency': {'amount': 250.0,
#     'currencyCode': 'USD'},
#    'daily': 250.0,
#    'discountSavingsText': None,
#    'monthly': 0.2,
#    'promotionResponse': None,
#    'weekly': 0.1},
#   'rating': None,
#   'rentableFromSearchedAirport': False,
#   'renterTripsTaken': 0,
#   'responseRate': None,
#   'responseTime': None,
#   'reviewCount': 0,
#   'turoGo': False,
#   'unlimitedMileageBadge': None,
#   'vehicle': {'automaticTransmission': True,
#    'id': 1898552,
#    'image': {'darkModeImageUrl': None,
#     'id': None,
#     'originalImageUrl': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.jpg',
#     'placeholder': False,
#     'resizableUrlTemplate': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.{width}x{height}.jpg',
#     'thumbnails': {'170x125': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '170x102': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.170x102.jpg',
#      '620x372': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '574x343': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.620x372.jpg',
#      '50x30': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.50x30.jpg',
#      '100x60': 'https://images.turo.com/media/vehicle/images/G1p-D75aSGu2-ejpfsFFYA.100x60.jpg'},
#     'verified': False},
#    'listingCreatedTime': 1676047812,
#    'make': 'Tesla',
#    'marketAreaId': None,
#    'marketCountry': 'US',
#    'model': 'Model S',
#    'name': 'NOT_USED',
#    'registration': None,
#    'trim': None,
#    'type': 'car',
#    'url': 'NOT_USED',
#    'vin': None,
#    'year': 2021,
#    'marketCurrency': {'currencyCode': 'USD',
#     'decimalPlaces': 2,
#     'defaultFractionDigits': 2,
#     'symbol': 'USD'}},
#   'vehicleFavoritedBySearcher': False,
#   'vehicleRentedBySearcher': False}]

# %%
###Conversion into dataframe
pd_list =pd.DataFrame(data_list)

# %%
pd_list =pd.DataFrame(data_list)

pd_list['rate'][0]
# Out:
# {'averageDailyPrice': 78.0,
#  'averageDailyPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#  'baseDailyRentalPriceWithCurrency': {'amount': 78.0, 'currencyCode': 'USD'},
#  'daily': 78.0,
#  'discountSavingsText': None,
#  'monthly': 0.15,
#  'promotionResponse': None,
#  'weekly': 0.07}

# %%
##Distance
distWithUnit = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in pd_list['distanceWithUnit']],ignore_index=True)
distWithUnit.head()
# Out:
#    scalar unit  unlimited
# 0      13   MI      False
# 1      20   MI      False
# 2      15   MI      False
# 3       9   MI      False
# 4       4   MI      False

# %%
##Images
images = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in pd_list['images']],ignore_index=True)
images.head()
# Out:
#   darkModeImageUrl    id                                   originalImageUrl  \
# 0             None  None  https://images.turo.com/media/vehicle/images/J...
# 1             None  None  https://images.turo.com/media/vehicle/images/K...
# 2             None  None  https://images.turo.com/media/vehicle/images/e...
# 3             None  None  https://images.turo.com/media/vehicle/images/k...
# 4             None  None  https://images.turo.com/media/vehicle/images/2...
#
#    placeholder                               resizableUrlTemplate  verified  \
# 0        False  https://images.turo.com/media/vehicle/images/J...     False
# 1        False  https://images.turo.com/media/vehicle/images/K...     False
# 2        False  https://images.turo.com/media/vehicle/images/e...     False
# 3        False  https://images.turo.com/media/vehicle/images/k...     False
# 4        False  https://images.turo.com/media/vehicle/images/2...     False
#
#                                   thumbnails.170x125  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                                   thumbnails.170x102  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                                   thumbnails.620x372  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                                   thumbnails.574x343  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                                     thumbnails.50x30  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                                    thumbnails.100x60
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...

# %%
##Location
location = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in pd_list['location']],ignore_index=True)
location.head()
print(location.columns)
# Out:
# Index(['address', 'addressLines', 'city', 'country', 'id', 'latitude',
#        'locationSource', 'longitude', 'state', 'timeZone',
#        'precision.accuracy', 'precision.level'],
#       dtype='object')

# %%
###Vehicle
vehicle = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in pd_list['vehicle']],ignore_index=True)
vehicle.head()
# Out:
#    automaticTransmission       id  listingCreatedTime    make marketAreaId  \
# 0                   True  1836352          1672098106  Toyota         None
# 1                   True  1546692          1655327798   Tesla         None
# 2                   True  1564500          1656205981  Toyota         None
# 3                   True   800214          1593846564   Tesla         None
# 4                   True  1869886          1674156409    Ford         None
#
#   marketCountry           model      name registration  trim  ...  \
# 0            US          Sienna  NOT_USED         None  None  ...
# 1            US         Model 3  NOT_USED         None  None  ...
# 2            US          Sienna  NOT_USED         None  None  ...
# 3            US         Model Y  NOT_USED         None  None  ...
# 4            US  Mustang Mach-E  NOT_USED         None  None  ...
#
#                             image.thumbnails.170x102  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                             image.thumbnails.620x372  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                             image.thumbnails.574x343  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                               image.thumbnails.50x30  \
# 0  https://images.turo.com/media/vehicle/images/J...
# 1  https://images.turo.com/media/vehicle/images/K...
# 2  https://images.turo.com/media/vehicle/images/e...
# 3  https://images.turo.com/media/vehicle/images/k...
# 4  https://images.turo.com/media/vehicle/images/2...
#
#                              image.thumbnails.100x60 image.verified  \
# 0  https://images.turo.com/media/vehicle/images/J...          False
# 1  https://images.turo.com/media/vehicle/images/K...          False
# 2  https://images.turo.com/media/vehicle/images/e...          False
# 3  https://images.turo.com/media/vehicle/images/k...          False
# 4  https://images.turo.com/media/vehicle/images/2...          False
#
#   marketCurrency.currencyCode  marketCurrency.decimalPlaces  \
# 0                         USD                             2
# 1                         USD                             2
# 2                         USD                             2
# 3                         USD                             2
# 4                         USD                             2
#
#   marketCurrency.defaultFractionDigits marketCurrency.symbol
# 0                                    2                   USD
# 1                                    2                   USD
# 2                                    2                   USD
# 3                                    2                   USD
# 4                                    2                   USD
#
# [5 rows x 30 columns]

# %%
##Rate
rate = pd.concat([pd.DataFrame(pd.json_normalize(x)) for x in pd_list['rate']],ignore_index=True)

# %%
###Creating separate dataframes for analysis
rate_df = rate[['averageDailyPrice','monthly','weekly']]
df=pd_list[['distance','rating','renterTripsTaken','reviewCount','responseRate','newListing','fuelType','responseTime']]
dist_with_unit_df =distWithUnit[['scalar','unit']]
Images_df=images[['originalImageUrl','thumbnails.170x102']]
location_df=location[['addressLines', 'city', 'country', 'latitude', 'longitude', 'state', 'timeZone']]
vehicle_df=vehicle[['model','make','id','listingCreatedTime','year','type','automaticTransmission']]

# %%
pdList = [df, dist_with_unit_df, Images_df, location_df, vehicle_df, rate_df]  # List of your dataframes
new_df = pd.concat(pdList,axis=1)

# %%
new_df['Model'] = new_df['model'].apply(lambda x : x.upper())

new_df['Make'] = new_df['make'].apply(lambda x : x.upper())

# %%
new_df
# Out:
#      distance  rating  renterTripsTaken  reviewCount responseRate  newListing  \
# 0        13.0     5.0                 7            0         None       False
# 1        20.0     5.0                40            0         None       False
# 2        15.0     5.0                17            0         None       False
# 3         9.0     5.0               117            0         None       False
# 4         4.0     5.0                 1            0         None       False
# ..        ...     ...               ...          ...          ...         ...
# 188       4.0     4.0                 2            0         None       False
# 189      14.0     4.5                 2            0         None       False
# 190      49.0     NaN                 0            0         None       False
# 191      21.0     5.0                 2            0         None       False
# 192      22.0     NaN                 0            0         None       False
#
#     fuelType responseTime  scalar unit  ...       id listingCreatedTime  year  \
# 0       None         None      13   MI  ...  1836352         1672098106  2023
# 1       None         None      20   MI  ...  1546692         1655327798  2021
# 2       None         None      15   MI  ...  1564500         1656205981  2022
# 3       None         None       9   MI  ...   800214         1593846564  2020
# 4       None         None       4   MI  ...  1869886         1674156409  2023
# ..       ...          ...     ...  ...  ...      ...                ...   ...
# 188     None         None       4   MI  ...  1846865         1672779389  2020
# 189     None         None      14   MI  ...  1508509         1653413215  2021
# 190     None         None      49   MI  ...  1923205         1677613946  2016
# 191     None         None      21   MI  ...  1535769         1654793531  2017
# 192     None         None      22   MI  ...  1898552         1676047812  2021
#
#         type automaticTransmission  averageDailyPrice  monthly weekly  \
# 0    minivan                  True               78.0     0.15   0.07
# 1        car                  True               65.0     0.15   0.12
# 2    minivan                  True               78.0     0.30   0.15
# 3        suv                  True               70.0     0.10   0.00
# 4        suv                  True               53.0     0.20   0.10
# ..       ...                   ...                ...      ...    ...
# 188      car                  True               90.0     0.30   0.15
# 189      suv                  True              250.0     0.00   0.00
# 190      suv                  True               99.0     0.30   0.15
# 191      car                  True               70.0     0.20   0.15
# 192      car                  True              250.0     0.20   0.10
#
#                  Model    Make
# 0               SIENNA  TOYOTA
# 1              MODEL 3   TESLA
# 2               SIENNA  TOYOTA
# 3              MODEL Y   TESLA
# 4       MUSTANG MACH-E    FORD
# ..                 ...     ...
# 188            MODEL 3   TESLA
# 189  HIGHLANDER HYBRID  TOYOTA
# 190            MODEL X   TESLA
# 191      FUSION HYBRID    FORD
# 192            MODEL S   TESLA
#
# [193 rows x 31 columns]

# %%
##!pip install openai
#import openai
#openai.api_key = "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"
#
#model_engine = "gpt-3.5-turbo" 
#
#def generate_response(prompt):
#
#    response = openai.ChatCompletion.create(
#        model='gpt-3.5-turbo',
#        engine = 
#        prompt=prompt,
#        temperature=0.5,
#        max_tokens=1024,
#        n=1,
#        stop=None,
#        frequency_penalty=0,
#        presence_penalty=0
#        
#    )
#    message = response.choices[0].text.strip()
#    return message
#
##message = response.choices[0]['message']
##print("{}: {}".format(message['role'], message['content']))
#message = generate_response('How are you?')
#print(message)

# %%
new_df[['model', 'make']]
# Out:
#                  model    make
# 0               Sienna  Toyota
# 1              Model 3   Tesla
# 2               Sienna  Toyota
# 3              Model Y   Tesla
# 4       Mustang Mach-E    Ford
# ..                 ...     ...
# 188            Model 3   Tesla
# 189  Highlander Hybrid  Toyota
# 190            Model X   Tesla
# 191      Fusion Hybrid    Ford
# 192            Model S   Tesla
#
# [193 rows x 2 columns]

# %%
###Loading EV 2 data
df_cars = pd.read_csv('Electric_Vehicle_Population_Data-2.csv')

# %%
df_cars
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJ3E1EA8J  San Diego      Oceanside    CA      92051.0        2018
# 1       3FA6P0PU7H   Sedgwick          Derby    KS      67037.0        2017
# 2       1N4AZ0CP8D  Snohomish     Marysville    WA      98271.0        2013
# 3       WBY8P8C58K     Kitsap      Bremerton    WA      98337.0        2019
# 4       5YJ3E1EA7K  Snohomish        Edmonds    WA      98026.0        2019
# ...            ...        ...            ...   ...          ...         ...
# 118954  5YJ3E1EB7N  Snohomish        Edmonds    WA      98020.0        2022
# 118955  1N4BZ0CP7H       King       Bellevue    WA      98004.0        2017
# 118956  1N4AZ1CP8J       King        Redmond    WA      98052.0        2018
# 118957  5YJXCAE41J       King        Seattle    WA      98109.0        2018
# 118958  YV4BR0CLXM     Island  Camano Island    WA      98282.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# 0        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 1         FORD   FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 2       NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 3          BMW       I3  Plug-in Hybrid Electric Vehicle (PHEV)
# 4        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# ...        ...      ...                                     ...
# 118954   TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 118955  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 118956  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 118957   TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 118958   VOLVO     XC90  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible             215
# 1                   Not eligible due to low battery range              21
# 2                 Clean Alternative Fuel Vehicle Eligible              75
# 3                 Clean Alternative Fuel Vehicle Eligible             126
# 4                 Clean Alternative Fuel Vehicle Eligible             220
# ...                                                   ...             ...
# 118954  Eligibility unknown as battery range has not b...               0
# 118955            Clean Alternative Fuel Vehicle Eligible             107
# 118956            Clean Alternative Fuel Vehicle Eligible             151
# 118957            Clean Alternative Fuel Vehicle Eligible             238
# 118958              Not eligible due to low battery range              18
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                   NaN       153998050
# 1               0                   NaN       138214331
# 2               0                  38.0         3129059
# 3               0                  26.0       166525635
# 4               0                  32.0       475248315
# ...           ...                   ...             ...
# 118954          0                  21.0       187322495
# 118955          0                  48.0       349474394
# 118956          0                  45.0       292721068
# 118957          0                  36.0       144355970
# 118958          0                  10.0       149075293
#
#                    Vehicle Location  \
# 0                               NaN
# 1        POINT (-97.27013 37.54531)
# 2       POINT (-122.19388 48.15353)
# 3         POINT (-122.62749 47.565)
# 4       POINT (-122.31768 47.87166)
# ...                             ...
# 118954  POINT (-122.37689 47.81116)
# 118955   POINT (-122.1872 47.61001)
# 118956  POINT (-122.13158 47.67858)
# 118957  POINT (-122.35022 47.63824)
# 118958  POINT (-122.40049 48.23986)
#
#                                          Electric Utility  2020 Census Tract
# 0                                                     NaN       6.073019e+09
# 1                                                     NaN       2.017301e+10
# 2                                  PUGET SOUND ENERGY INC       5.306105e+10
# 3                                  PUGET SOUND ENERGY INC       5.303508e+10
# 4                                  PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                   ...                ...
# 118954                             PUGET SOUND ENERGY INC       5.306105e+10
# 118955      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 118956      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 118957       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 118958  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.302997e+10
#
# [118959 rows x 17 columns]

# %%
car_make_model = new_df[['model', 'make']]
car_make_model.rename(columns={'model': 'Model', 'make': 'Make'}, inplace=True)
# Out:
# /var/folders/12/wrdf3scj0fb6r95lfqzfcbqr0000gn/T/ipykernel_9915/1966619945.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_make_model.rename(columns={'model': 'Model', 'make': 'Make'}, inplace=True)

# %%
small_make_model = df_cars[['Make', 'Model']]

# %%
###Creation of a new dataset

inner_join = pd.merge(car_make_model, 
                      small_make_model, 
                      on =['Make','Model'],
                      how ='inner')

# %%
inner_join
# Out:
#      Model Make
# 0       X5  BMW
# 1       X5  BMW
# 2       X5  BMW
# 3       X5  BMW
# 4       X5  BMW
# ...    ...  ...
# 1801    I8  BMW
# 1802    I8  BMW
# 1803    I8  BMW
# 1804    I8  BMW
# 1805    I8  BMW
#
# [1806 rows x 2 columns]

# %%
main_df = pd.merge(df_cars, new_df, on =['Make','Model'],how ='left')

# %%
main_df
print(type(main_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
###Removal of duplicates
new_df_1 = main_df.drop_duplicates
print(new_df_1)
# Out:
# <bound method DataFrame.drop_duplicates of          VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0        5YJ3E1EA8J  San Diego      Oceanside    CA      92051.0        2018
# 1        5YJ3E1EA8J  San Diego      Oceanside    CA      92051.0        2018
# 2        5YJ3E1EA8J  San Diego      Oceanside    CA      92051.0        2018
# 3        5YJ3E1EA8J  San Diego      Oceanside    CA      92051.0        2018
# 4        5YJ3E1EA8J  San Diego      Oceanside    CA      92051.0        2018
# ...             ...        ...            ...   ...          ...         ...
# 1812083  5YJXCAE41J       King        Seattle    WA      98109.0        2018
# 1812084  5YJXCAE41J       King        Seattle    WA      98109.0        2018
# 1812085  5YJXCAE41J       King        Seattle    WA      98109.0        2018
# 1812086  5YJXCAE41J       King        Seattle    WA      98109.0        2018
# 1812087  YV4BR0CLXM     Island  Camano Island    WA      98282.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# 0        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 1        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 2        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 3        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 4        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# ...        ...      ...                                     ...
# 1812083  TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 1812084  TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 1812085  TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 1812086  TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 1812087  VOLVO     XC90  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  ...    model  \
# 0                 Clean Alternative Fuel Vehicle Eligible  ...  Model 3
# 1                 Clean Alternative Fuel Vehicle Eligible  ...  Model 3
# 2                 Clean Alternative Fuel Vehicle Eligible  ...  Model 3
# 3                 Clean Alternative Fuel Vehicle Eligible  ...  Model 3
# 4                 Clean Alternative Fuel Vehicle Eligible  ...  Model 3
# ...                                                   ...  ...      ...
# 1812083           Clean Alternative Fuel Vehicle Eligible  ...  Model X
# 1812084           Clean Alternative Fuel Vehicle Eligible  ...  Model X
# 1812085           Clean Alternative Fuel Vehicle Eligible  ...  Model X
# 1812086           Clean Alternative Fuel Vehicle Eligible  ...  Model X
# 1812087             Not eligible due to low battery range  ...      NaN
#
#           make         id  listingCreatedTime    year type  \
# 0        Tesla  1546692.0        1.655328e+09  2021.0  car
# 1        Tesla  1289806.0        1.639168e+09  2021.0  car
# 2        Tesla  1719859.0        1.664318e+09  2019.0  car
# 3        Tesla  1685823.0        1.662232e+09  2022.0  car
# 4        Tesla  1748187.0        1.666055e+09  2022.0  car
# ...        ...        ...                 ...     ...  ...
# 1812083  Tesla  1710669.0        1.663736e+09  2022.0  suv
# 1812084  Tesla  1880648.0        1.674860e+09  2023.0  suv
# 1812085  Tesla  1697533.0        1.662956e+09  2022.0  suv
# 1812086  Tesla  1923205.0        1.677614e+09  2016.0  suv
# 1812087    NaN        NaN                 NaN     NaN  NaN
#
#          automaticTransmission  averageDailyPrice  monthly  weekly
# 0                         True               65.0     0.15    0.12
# 1                         True               74.0     0.40    0.25
# 2                         True               78.0     0.15    0.10
# 3                         True               64.0     0.10    0.00
# 4                         True               63.0     0.08    0.05
# ...                        ...                ...      ...     ...
# 1812083                   True              179.0     0.00    0.00
# 1812084                   True              170.0     0.25    0.15
# 1812085                   True              149.0     0.20    0.10
# 1812086                   True               99.0     0.30    0.15
# 1812087                    NaN                NaN      NaN     NaN
#
# [1812088 rows x 46 columns]>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/12/wrdf3scj0fb6r95lfqzfcbqr0000gn/T/ipykernel_9915/3139132029.py in <module>
# ----> 1 new_df_1.columns()
#
# AttributeError: 'function' object has no attribute 'columns'

# %%
grouped_attributes = new_df.groupby(['Make','Model'])
grp_atri_df = grouped_attributes.first()

# %%
grp_atri_df.columns

# %%
####Addition of attributes

lookup_table = grp_atri_df[['rating','renterTripsTaken','reviewCount','type']]

# %%
main = pd.merge(df_cars, lookup_table, on =['Make','Model'],how ='inner')

# %%
print((main['Vehicle Location'][1]))

# %%
print((main['Vehicle Location'][1].split(' ',1))[1].split())

# %%
####Co-ordinates extraction

import re

#s = "POINT (-122.31768 47.87166)"
#numbers = re.findall(r"[-+]?\d*\.\d+|\d+", s)

main = main.dropna()

main['Vehicle Location'].apply(lambda x: re.findall(r"[-+]?\d*\.\d+|\d+", x))


#print(numbers)

# %%
main

main['lat'] = main['Vehicle Location'].apply(lambda x: x[0])
main['lng'] = main['Vehicle Location'].apply(lambda x: x[1])

# %%
###Forming the final dataset
main_csv_data = df.to_csv('ev.csv', index = True)
# Out:
#        VIN (1-10)     County           City State  Postal Code  Model Year  \
# 1      5YJ3E1EA7K  Snohomish        Edmonds    WA      98026.0        2019
# 2      5YJ3E1EA1L  Snohomish        Bothell    WA      98021.0        2020
# 3      5YJ3E1EB8K   Thurston        Olympia    WA      98501.0        2019
# 4      5YJ3E1EA4J     Skagit      Anacortes    WA      98221.0        2018
# 5      5YJ3E1EBXL  Snohomish        Bothell    WA      98012.0        2020
# ...           ...        ...            ...   ...          ...         ...
# 85031  4JGDA6DB7G      Lewis      Centralia    WA      98531.0        2016
# 85032  4JGDA6DB7H       King         Renton    WA      98058.0        2017
# 85033  4JGDA6DB9J       King       Kirkland    WA      98033.0        2018
# 85034  4JGDA6DB3J       King       Bellevue    WA      98006.0        2018
# 85035  4JGDA6DB2J       King  Mercer Island    WA      98040.0        2018
#
#                 Make      Model                   Electric Vehicle Type  \
# 1              TESLA    MODEL 3          Battery Electric Vehicle (BEV)
# 2              TESLA    MODEL 3          Battery Electric Vehicle (BEV)
# 3              TESLA    MODEL 3          Battery Electric Vehicle (BEV)
# 4              TESLA    MODEL 3          Battery Electric Vehicle (BEV)
# 5              TESLA    MODEL 3          Battery Electric Vehicle (BEV)
# ...              ...        ...                                     ...
# 85031  MERCEDES-BENZ  GLE-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 85032  MERCEDES-BENZ  GLE-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 85033  MERCEDES-BENZ  GLE-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 85034  MERCEDES-BENZ  GLE-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 85035  MERCEDES-BENZ  GLE-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  ...  DOL Vehicle ID  \
# 1               Clean Alternative Fuel Vehicle Eligible  ...       475248315
# 2               Clean Alternative Fuel Vehicle Eligible  ...       110771972
# 3               Clean Alternative Fuel Vehicle Eligible  ...       477769939
# 4               Clean Alternative Fuel Vehicle Eligible  ...       258609291
# 5               Clean Alternative Fuel Vehicle Eligible  ...       106295451
# ...                                                 ...  ...             ...
# 85031             Not eligible due to low battery range  ...       227458521
# 85032             Not eligible due to low battery range  ...       350195716
# 85033             Not eligible due to low battery range  ...       133748198
# 85034             Not eligible due to low battery range  ...       348274552
# 85035             Not eligible due to low battery range  ...       128812302
#
#              Vehicle Location  \
# 1      [-122.31768, 47.87166]
# 2       [-122.18384, 47.8031]
# 3      [-122.89166, 47.03956]
# 4      [-122.61214, 48.51748]
# 5      [-122.21061, 47.83448]
# ...                       ...
# 85031  [-122.95298, 46.72894]
# 85032   [-122.08747, 47.4466]
# 85033   [-122.2066, 47.67887]
# 85034  [-122.12096, 47.55584]
# 85035  [-122.21238, 47.57816]
#
#                                         Electric Utility  2020 Census Tract  \
# 1                                 PUGET SOUND ENERGY INC       5.306105e+10
# 2                                 PUGET SOUND ENERGY INC       5.306105e+10
# 3                                 PUGET SOUND ENERGY INC       5.306701e+10
# 4                                 PUGET SOUND ENERGY INC       5.305794e+10
# 5                                 PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                  ...                ...
# 85031  BONNEVILLE POWER ADMINISTRATION||CITY OF CENTR...       5.304197e+10
# 85032      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 85033      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 85034      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 85035      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
#
#       rating renterTripsTaken  reviewCount  type         lat       lng
# 1        5.0               40            0   car  -122.31768  47.87166
# 2        5.0               40            0   car  -122.18384   47.8031
# 3        5.0               40            0   car  -122.89166  47.03956
# 4        5.0               40            0   car  -122.61214  48.51748
# 5        5.0               40            0   car  -122.21061  47.83448
# ...      ...              ...          ...   ...         ...       ...
# 85031    5.0                2            0   suv  -122.95298  46.72894
# 85032    5.0                2            0   suv  -122.08747   47.4466
# 85033    5.0                2            0   suv   -122.2066  47.67887
# 85034    5.0                2            0   suv  -122.12096  47.55584
# 85035    5.0                2            0   suv  -122.21238  47.57816
#
# [80572 rows x 23 columns]
